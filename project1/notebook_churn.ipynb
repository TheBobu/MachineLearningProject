# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io.arff import loadarff
import missingno as msno

# %% [markdown]
# Load dataset

# %%
raw_data = loadarff("./../datasets/churn.arff")

churn_df = pd.DataFrame(raw_data[0])

# %% [markdown]
# Operations

# %%
churn_df.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class'],
#       dtype='object')

# %%
msno.matrix(churn_df)
# Out:
# <AxesSubplot:>

# %%
churn_df.head()
# Out:
#    state  account_length area_code  phone_number international_plan  \
# 0   16.0           128.0    b'415'        2845.0               b'0'
# 1   35.0           107.0    b'415'        2301.0               b'0'
# 2   31.0           137.0    b'415'        1616.0               b'0'
# 3   35.0            84.0    b'408'        2510.0               b'1'
# 4   36.0            75.0    b'415'         155.0               b'1'
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0            b'1'                   25.0              265.1            110.0
# 1            b'1'                   26.0              161.6            123.0
# 2            b'0'                    0.0              243.4            114.0
# 3            b'0'                    0.0              299.4             71.0
# 4            b'0'                    0.0              166.7            113.0
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...
